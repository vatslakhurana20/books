# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval

# %%
# handle certificate verification and SSL warnings
# https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())

# %%
# get data from the API
url = 'https://api.themoviedb.org/3/discover/movie?with_genres=27&with_original_language=hi|kn|ml|ta|te&api_key=d08aea0bd49352097d28659b824a26b6'
r = http.request('GET', url)
r.status
# Out:
# 200

# %%
# decode json data into a dict object
data = json.loads(r.data.decode('utf-8'))
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/kIszdVMM7Dezzrs0P7jUcMkG3o8.jpg',
#    'genre_ids': [27, 14],
#    'id': 714338,
#    'original_language': 'hi',
#    'original_title': 'Bulbbul',
#    'overview': 'A child bride grows up to be an enigmatic woman presiding over her household, harboring a painful past as supernatural murders of men plague her village.',
#    'popularity': 27.028,
#    'poster_path': '/4XYEqHqvcf6vxFhNyeKZz5xbUfV.jpg',
#    'release_date': '2020-06-24',
#    'title': 'Bulbbul',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 57},
#   {'adult': False,
#    'backdrop_path': '/ndO0KTkql6zr0u0cQ6gOsqpgpUd.jpg',
#    'genre_ids': [27, 14],
#    'id': 538858,
#    'original_language': 'hi',
#    'original_title': 'तुम्बाड',
#    'overview': 'India, 1918. On the outskirts of Tumbbad, a cursed village where it always rains, Vinayak, along with his mother and his brother, care of a mysterious old woman who keeps the secret of an ancestral treasure that Vinayak gets obsessed with.',
#    'popularity': 6.267,
#    'poster_path': '/5Q3Iz5YaGZVnvk3tjDDrW71iaym.jpg',
#    'release_date': '2018-10-12',
#    'title': 'Tumbbad',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 105},
#   {'adult': False,
#    'backdrop_path': '/dKSykSoV8eGWYqgmVJwBpBvTPzz.jpg',
#    'genre_ids': [27],
#    'id': 601643,
#    'original_language': 'hi',
#    'original_title': 'Ghost Stories',
#    'overview': 'An anthology of four short horror tales.',
#    'popularity': 8.424,
#    'poster_path': '/wuTwPYFoEGQG3EntpdZA8LlBBdx.jpg',
#    'release_date': '2020-01-01',
#    'title': 'Ghost Stories',
#    'video': False,
#    'vote_average': 4.7,
#    'vote_count': 38},
#   {'adult': False,
#    'backdrop_path': '/lDiRA1SkMLVduOaOmn6V0vg3c0h.jpg',
#    'genre_ids': [35, 27, 53],
#    'id': 19025,
#    'original_language': 'hi',
#    'original_title': 'भूल भुलैया',
#    'overview': "When U.S.-based Siddharth visits his Indian home town with his new wife, he insists they stay at the ancestral home, laughing off family members' warnings of ghostly goings-on in the mansion. But events soon make him reconsider his beliefs. As unexplained and terrifying occurrences arise, Siddharth calls on his doctor friend to help solve the mystery. What will be the outcome? Will Siddharth's friend be able to solve this riddle?",
#    'popularity': 6.864,
#    'poster_path': '/soRW3p4GlPphHiFkwbqYGrodQ5S.jpg',
#    'release_date': '2007-10-12',
#    'title': 'Bhool Bhulaiyaa',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 96},
#   {'adult': False,
#    'backdrop_path': '/eJPky5hssaNpjVRS5XMB3gkgJrQ.jpg',
#    'genre_ids': [27, 35],
#    'id': 533991,
#    'original_language': 'hi',
#    'original_title': 'स्त्री',
#    'overview': 'Set in the town of Chanderi, Stree is based on the urban legend of Nale Ba that went viral in Karnataka in the 1990s, and features Shraddha Kapoor and Rajkummar Rao in pivotal roles.',
#    'popularity': 7.421,
#    'poster_path': '/vkbSB8U9uPN18ssXCf8taetBae.jpg',
#    'release_date': '2018-08-31',
#    'title': 'Stree',
#    'video': False,
#    'vote_average': 7,
#    'vote_count': 80},
#   {'adult': False,
#    'backdrop_path': '/hbVQ8B6k1XyRCa1aGQluyyT4LOX.jpg',
#    'genre_ids': [27, 53],
#    'id': 616880,
#    'original_language': 'hi',
#    'original_title': 'Bhoot: Part One - The Haunted Ship',
#    'overview': "When an abandoned haunted ship called 'Sea Bird' washes up on the shores of Mumbai, surveying officer Prithvi is assigned to solve the mystery and close the case",
#    'popularity': 4.693,
#    'poster_path': '/5rSRVvlIlelgKM58MAnnk4FId86.jpg',
#    'release_date': '2020-02-21',
#    'title': 'Bhoot: Part One - The Haunted Ship',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 15},
#   {'adult': False,
#    'backdrop_path': '/2JTqYozAkCUga9LSq64gI9CJ8Bm.jpg',
#    'genre_ids': [35, 27, 28, 14],
#    'id': 472123,
#    'original_language': 'hi',
#    'original_title': 'गोलमाल अगेन',
#    'overview': 'Gopal and his best friends are back again, and this time they move back to their old neighborhood in a new palatial house where they learn that it is being haunted by a ghost.',
#    'popularity': 4.463,
#    'poster_path': '/kGx26PL1v658T8XbOk5MfmNpHU3.jpg',
#    'release_date': '2017-10-20',
#    'title': 'Golmaal Again',
#    'video': False,
#    'vote_average': 5.5,
#    'vote_count': 57},
#   {'adult': False,
#    'backdrop_path': '/qQGKo21qes7ZjsJqKSSnfUBghKM.jpg',
#    'genre_ids': [53, 27],
#    'id': 648705,
#    'original_language': 'te',
#    'original_title': 'నిశ్శబ్దం',
#    'overview': 'Seattle PD is investigating the murder of a man and Sakshi, a deaf and mute artist, and her husband Antony, a renowned cello player, are related to it.',
#    'popularity': 4.01,
#    'poster_path': '/mz4hwTvyU4AERcgZxY1rpL2A8sv.jpg',
#    'release_date': '2020-10-02',
#    'title': 'Nishabdham',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 5},
#   {'adult': False,
#    'backdrop_path': '/lHyphBOFj1gv2Ykg5dmRtxWx92M.jpg',
#    'genre_ids': [27, 53],
#    'id': 553456,
#    'original_language': 'ta',
#    'original_title': 'கேம் ஓவர்',
#    'overview': 'Swapna, a nyctophobic game designer, is on a turbulent road to recovery from an incident that scarred her deeply, has to fight her inner demons to stay alive in the game called life.',
#    'popularity': 4.406,
#    'poster_path': '/wBUt6oTFZOMN1skbhIq0gpxpe6J.jpg',
#    'release_date': '2019-06-14',
#    'title': 'Game Over',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 39},
#   {'adult': False,
#    'backdrop_path': '/2pGBScm9WFQhDRL0ZljVgbWdhWP.jpg',
#    'genre_ids': [18, 9648, 27],
#    'id': 19950,
#    'original_language': 'ta',
#    'original_title': 'யாவரும் நலம்',
#    'overview': "Manohar, an upwardly mobile middle class Indian moves into a new apartment -13B on the 13th floor with his family. From the first day in their new home, the women are hooked on to a new TV show 'Sab Khairiyat'. The show is about a family eerily similar to theirs who have also just moved into a new house. As the TV show unfolds, all the incidents that happen in the show start happening to them.",
#    'popularity': 4.427,
#    'poster_path': '/pb1Dm4lKpqdqXdsX1piIIiTaTGj.jpg',
#    'release_date': '2009-03-06',
#    'title': 'Yavarum Nalam',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 46},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [27],
#    'id': 586467,
#    'original_language': 'hi',
#    'original_title': 'Rakkhosh',
#    'overview': 'The movie explores the horrors and fantasies of a patient trapped in a mental asylum.',
#    'popularity': 2.675,
#    'poster_path': '/xyT4t6PFTF0uF9iNNhm81oFvdFL.jpg',
#    'release_date': '2019-01-20',
#    'title': 'Rakkhosh',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 8},
#   {'adult': False,
#    'backdrop_path': '/yCNnj1s6CoAOehejo27TV8gtOKe.jpg',
#    'genre_ids': [27, 35],
#    'id': 603673,
#    'original_language': 'hi',
#    'original_title': 'लक्ष्मी',
#    'overview': "Aasif's belief in logic and science shatters when he gets possessed by a transgender's ghost.",
#    'popularity': 4.18,
#    'poster_path': '/9sZ1UGVxOCs4yDd5NoACRkK0oXn.jpg',
#    'release_date': '2020-11-09',
#    'title': 'Laxmii',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 11},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35, 27],
#    'id': 191562,
#    'original_language': 'hi',
#    'original_title': 'गो गोआ गॉन',
#    'overview': 'A rave party off the coast of Goa goes horrifyingly and hilariously wrong when the island is overrun with zombies.',
#    'popularity': 4.93,
#    'poster_path': '/5yArWoxijgN0gvo0ExQfKXgZ0Qr.jpg',
#    'release_date': '2013-05-10',
#    'title': 'Go Goa Gone',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 68},
#   {'adult': False,
#    'backdrop_path': '/dIvfMOPSLWiTPWU4iN94Vtn6XNN.jpg',
#    'genre_ids': [27, 14, 9648],
#    'id': 461649,
#    'original_language': 'hi',
#    'original_title': 'परी',
#    'overview': 'Arnab tries to help Ruksahana, who is found under mysterious circumstances in a house. He lets her stay at his home until he discovers something strange about her.',
#    'popularity': 3.983,
#    'poster_path': '/togwv0TGqXkIA2YuYIY9VDLEkdF.jpg',
#    'release_date': '2018-03-02',
#    'title': 'Pari',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 28},
#   {'adult': False,
#    'backdrop_path': '/lzqfTGdgXyYJVrO6AjscS0NscR7.jpg',
#    'genre_ids': [27],
#    'id': 242441,
#    'original_language': 'hi',
#    'original_title': 'Horror Story',
#    'overview': 'A group of 7 youngsters-4 guys and 3 girls decide to spend a night at a reportedly haunted hotel to celebrate the farewell of one of them leaving for the USA. Despite people\'s warnings and other "signs" trying to ward them off from there, they enter the hotel, and then the truth dawns on them.  Seven friends - Sam alias Samrat, Magesh, Achint, Neel, Neena, Sonia and Magi reunite after several years apart to celebrate the farewell of one of their friends, who is going abroad in order to pursue his career and fulfill his goals. The group soon learns about an abandoned hotel with strange stories around it. Much against warnings, they decide to spend a night at the hotel, and soon realize the mistake of their lives',
#    'popularity': 2.79,
#    'poster_path': '/qcl0udYtSSrSsh1ThVCOdCBljph.jpg',
#    'release_date': '2013-09-13',
#    'title': 'Horror Story',
#    'video': False,
#    'vote_average': 4.5,
#    'vote_count': 47},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35, 27],
#    'id': 330425,
#    'original_language': 'ta',
#    'original_title': 'காஞ்சனா 2',
#    'overview': 'A TV channel’s crew goes to a deserted beachside bungalow to stage a horror show but the place is actually haunted and the ghost(s) in the place possess the director and the cameraman in the team.',
#    'popularity': 4.609,
#    'poster_path': '/oBaVzegjQza23C1XCOMfnQRhplw.jpg',
#    'release_date': '2015-04-17',
#    'title': 'Kanchana 2',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 17},
#   {'adult': False,
#    'backdrop_path': '/xbRIRQKKGJHEUB45AEH39ZCZNda.jpg',
#    'genre_ids': [14, 27, 9648, 53],
#    'id': 84368,
#    'original_language': 'ml',
#    'original_title': 'മണിച്ചിത്രത്താഴ്',
#    'overview': "A young couple, Ganga and Nakulan, arrives at the ancestral home called Madampalli of the latter. Hailing from a family that follows tradition and superstitions, Nakulan's uncle Thampi objects to the couple's idea of moving into the allegedly haunted mansion, which Nakulan ignores. The couple moves in anyway following which seemingly supernatural events begin to happen.",
#    'popularity': 4.388,
#    'poster_path': '/5YccrqvJFTfAVyEZp08I3fLx15y.jpg',
#    'release_date': '1993-12-25',
#    'title': 'Manichitrathazhu',
#    'video': False,
#    'vote_average': 7.6,
#    'vote_count': 52},
#   {'adult': False,
#    'backdrop_path': '/mZ8Zba9P0LHr37p98I11WVxs0d6.jpg',
#    'genre_ids': [80, 27, 9648, 53],
#    'id': 397490,
#    'original_language': 'kn',
#    'original_title': 'ಮಗಳು ಜಾನಕಿ',
#    'overview': 'A journalist who intents to write an article on traffic rule breakers gets dragged into a whirlpool of murder cases and deception.',
#    'popularity': 3.59,
#    'poster_path': '/fjl9czd3zj0QpeaXAysAGwM9UrD.jpg',
#    'release_date': '2016-05-20',
#    'title': 'U Turn',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 27},
#   {'adult': False,
#    'backdrop_path': '/7GuYHiwBEnZ6ulinOOJAHLjlYRE.jpg',
#    'genre_ids': [14, 27],
#    'id': 371420,
#    'original_language': 'ta',
#    'original_title': 'காஷ்மோரா',
#    'overview': 'Kaashmora, a present era black magic specialist; Rajnayak, an ancient era warlord and Ratnamahadevi is his queen. How these three are connected? What are the issues that arise?',
#    'popularity': 4.028,
#    'poster_path': '/fhWdd4obIA9ASc7xYfo38JyLqpQ.jpg',
#    'release_date': '2016-10-28',
#    'title': 'Kaashmora',
#    'video': False,
#    'vote_average': 4.8,
#    'vote_count': 17},
#   {'adult': False,
#    'backdrop_path': '/n3wpP3gQQ8coi7rAwAXYzjM6iMH.jpg',
#    'genre_ids': [27, 53],
#    'id': 480308,
#    'original_language': 'ta',
#    'original_title': 'அவள்',
#    'overview': 'Two families have a tough time dealing with a revenge-seeking spirit, which is strangely connected with one of its members',
#    'popularity': 2.569,
#    'poster_path': '/7Xm7x3VKPsld8N3OCVu3krbPAFu.jpg',
#    'release_date': '2017-11-02',
#    'title': 'Aval',
#    'video': False,
#    'vote_average': 5.7,
#    'vote_count': 27}],
#  'total_pages': 23,
#  'total_results': 450}

# %%
# in this dataset, the data to extract is under 'features'
df = pd.json_normalize(data, 'results')
df
# Out:
#     adult                     backdrop_path           genre_ids      id  \
# 0   False  /kIszdVMM7Dezzrs0P7jUcMkG3o8.jpg            [27, 14]  714338
# 1   False  /ndO0KTkql6zr0u0cQ6gOsqpgpUd.jpg            [27, 14]  538858
# 2   False  /dKSykSoV8eGWYqgmVJwBpBvTPzz.jpg                [27]  601643
# 3   False  /lDiRA1SkMLVduOaOmn6V0vg3c0h.jpg        [35, 27, 53]   19025
# 4   False  /eJPky5hssaNpjVRS5XMB3gkgJrQ.jpg            [27, 35]  533991
# 5   False  /hbVQ8B6k1XyRCa1aGQluyyT4LOX.jpg            [27, 53]  616880
# 6   False  /2JTqYozAkCUga9LSq64gI9CJ8Bm.jpg    [35, 27, 28, 14]  472123
# 7   False  /qQGKo21qes7ZjsJqKSSnfUBghKM.jpg            [53, 27]  648705
# 8   False  /lHyphBOFj1gv2Ykg5dmRtxWx92M.jpg            [27, 53]  553456
# 9   False  /2pGBScm9WFQhDRL0ZljVgbWdhWP.jpg      [18, 9648, 27]   19950
# 10  False                              None                [27]  586467
# 11  False  /yCNnj1s6CoAOehejo27TV8gtOKe.jpg            [27, 35]  603673
# 12  False                              None            [35, 27]  191562
# 13  False  /dIvfMOPSLWiTPWU4iN94Vtn6XNN.jpg      [27, 14, 9648]  461649
# 14  False  /lzqfTGdgXyYJVrO6AjscS0NscR7.jpg                [27]  242441
# 15  False                              None            [35, 27]  330425
# 16  False  /xbRIRQKKGJHEUB45AEH39ZCZNda.jpg  [14, 27, 9648, 53]   84368
# 17  False  /mZ8Zba9P0LHr37p98I11WVxs0d6.jpg  [80, 27, 9648, 53]  397490
# 18  False  /7GuYHiwBEnZ6ulinOOJAHLjlYRE.jpg            [14, 27]  371420
# 19  False  /n3wpP3gQQ8coi7rAwAXYzjM6iMH.jpg            [27, 53]  480308
#
#    original_language                      original_title  \
# 0                 hi                             Bulbbul
# 1                 hi                             तुम्बाड
# 2                 hi                       Ghost Stories
# 3                 hi                          भूल भुलैया
# 4                 hi                              स्त्री
# 5                 hi  Bhoot: Part One - The Haunted Ship
# 6                 hi                         गोलमाल अगेन
# 7                 te                           నిశ్శబ్దం
# 8                 ta                           கேம் ஓவர்
# 9                 ta                        யாவரும் நலம்
# 10                hi                            Rakkhosh
# 11                hi                             लक्ष्मी
# 12                hi                          गो गोआ गॉन
# 13                hi                                 परी
# 14                hi                        Horror Story
# 15                ta                           காஞ்சனா 2
# 16                ml                    മണിച്ചിത്രത്താഴ്
# 17                kn                          ಮಗಳು ಜಾನಕಿ
# 18                ta                            காஷ்மோரா
# 19                ta                                அவள்
#
#                                              overview  popularity  \
# 0   A child bride grows up to be an enigmatic woma...      27.028
# 1   India, 1918. On the outskirts of Tumbbad, a cu...       6.267
# 2            An anthology of four short horror tales.       8.424
# 3   When U.S.-based Siddharth visits his Indian ho...       6.864
# 4   Set in the town of Chanderi, Stree is based on...       7.421
# 5   When an abandoned haunted ship called 'Sea Bir...       4.693
# 6   Gopal and his best friends are back again, and...       4.463
# 7   Seattle PD is investigating the murder of a ma...       4.010
# 8   Swapna, a nyctophobic game designer, is on a t...       4.406
# 9   Manohar, an upwardly mobile middle class India...       4.427
# 10  The movie explores the horrors and fantasies o...       2.675
# 11  Aasif's belief in logic and science shatters w...       4.180
# 12  A rave party off the coast of Goa goes horrify...       4.930
# 13  Arnab tries to help Ruksahana, who is found un...       3.983
# 14  A group of 7 youngsters-4 guys and 3 girls dec...       2.790
# 15  A TV channel’s crew goes to a deserted beachsi...       4.609
# 16  A young couple, Ganga and Nakulan, arrives at ...       4.388
# 17  A journalist who intents to write an article o...       3.590
# 18  Kaashmora, a present era black magic specialis...       4.028
# 19  Two families have a tough time dealing with a ...       2.569
#
#                          poster_path release_date  \
# 0   /4XYEqHqvcf6vxFhNyeKZz5xbUfV.jpg   2020-06-24
# 1   /5Q3Iz5YaGZVnvk3tjDDrW71iaym.jpg   2018-10-12
# 2   /wuTwPYFoEGQG3EntpdZA8LlBBdx.jpg   2020-01-01
# 3   /soRW3p4GlPphHiFkwbqYGrodQ5S.jpg   2007-10-12
# 4    /vkbSB8U9uPN18ssXCf8taetBae.jpg   2018-08-31
# 5   /5rSRVvlIlelgKM58MAnnk4FId86.jpg   2020-02-21
# 6   /kGx26PL1v658T8XbOk5MfmNpHU3.jpg   2017-10-20
# 7   /mz4hwTvyU4AERcgZxY1rpL2A8sv.jpg   2020-10-02
# 8   /wBUt6oTFZOMN1skbhIq0gpxpe6J.jpg   2019-06-14
# 9   /pb1Dm4lKpqdqXdsX1piIIiTaTGj.jpg   2009-03-06
# 10  /xyT4t6PFTF0uF9iNNhm81oFvdFL.jpg   2019-01-20
# 11  /9sZ1UGVxOCs4yDd5NoACRkK0oXn.jpg   2020-11-09
# 12  /5yArWoxijgN0gvo0ExQfKXgZ0Qr.jpg   2013-05-10
# 13  /togwv0TGqXkIA2YuYIY9VDLEkdF.jpg   2018-03-02
# 14  /qcl0udYtSSrSsh1ThVCOdCBljph.jpg   2013-09-13
# 15  /oBaVzegjQza23C1XCOMfnQRhplw.jpg   2015-04-17
# 16  /5YccrqvJFTfAVyEZp08I3fLx15y.jpg   1993-12-25
# 17  /fjl9czd3zj0QpeaXAysAGwM9UrD.jpg   2016-05-20
# 18  /fhWdd4obIA9ASc7xYfo38JyLqpQ.jpg   2016-10-28
# 19  /7Xm7x3VKPsld8N3OCVu3krbPAFu.jpg   2017-11-02
#
#                                  title  video  vote_average  vote_count
# 0                              Bulbbul  False           6.9          57
# 1                              Tumbbad  False           7.7         105
# 2                        Ghost Stories  False           4.7          38
# 3                      Bhool Bhulaiyaa  False           6.4          96
# 4                                Stree  False           7.0          80
# 5   Bhoot: Part One - The Haunted Ship  False           6.6          15
# 6                        Golmaal Again  False           5.5          57
# 7                           Nishabdham  False           5.8           5
# 8                            Game Over  False           6.3          39
# 9                        Yavarum Nalam  False           6.1          46
# 10                            Rakkhosh  False           6.1           8
# 11                              Laxmii  False           6.8          11
# 12                         Go Goa Gone  False           5.8          68
# 13                                Pari  False           6.5          28
# 14                        Horror Story  False           4.5          47
# 15                          Kanchana 2  False           5.7          17
# 16                    Manichitrathazhu  False           7.6          52
# 17                              U Turn  False           6.8          27
# 18                           Kaashmora  False           4.8          17
# 19                                Aval  False           5.7          27

# %%
movie_id=df['id']

for i in movie_id.values():
    http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
    url = 'https://api.themoviedb.org/3/movie/'+{}+'/credits?api_key=d08aea0bd49352097d28659b824a26b6&language=en-US'
    url=url.format(i)
    r = http.request('GET', url)
    r.status
    data = json.loads(r.data.decode('utf-8'))
    data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2a1fbc4f1623> in <module>
#       1 movie_id=df['id']
# ----> 2 movie_id.type()
#       3 for i in movie_id.values():
#       4     http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
#       5     url = 'https://api.themoviedb.org/3/movie/'+{}+'/credits?api_key=d08aea0bd49352097d28659b824a26b6&language=en-US'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'
